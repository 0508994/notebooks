# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import random

style.use('fivethirtyeight')

# %%
x = np.random.randn(50)

# old style
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222, sharex=ax1, sharey=ax1)
ax3 = fig.add_subplot(223, sharex=ax1, sharey=ax1)
ax4 = fig.add_subplot(224, sharex=ax1, sharey=ax1)

ax1.plot(np.random.randn(50))
ax2.plot(np.random.randn(50))
ax3.plot(np.random.randn(50))
ax4.plot(np.random.randn(50))

plt.show()

# %%
# new style method 1; unpack the axes
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True)
ax1.plot(x)
plt.show()

# %%
# sentdex
def create_plot():
    x = []
    y = []
    for i in range(10):
        x.append(i)
        y.append(random.randrange(10))        
    return x, y

fig  = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

x, y = create_plot()
ax1.plot(x, y, c='m')
x, y = create_plot()
ax2.plot(x, y)

plt.show()

# %%
# subplottogrid
ax1 = plt.subplot2grid((6, 1), (0, 0), rowspan=1, colspan=1)
ax2 = plt.subplot2grid((6, 1), (1, 0), rowspan=4, colspan=1)
ax3 = plt.subplot2grid((6, 1), (5, 0), rowspan=1, colspan=1)

x, y = create_plot()
ax1.plot(x, y)
x, y = create_plot()
ax2.plot(x, y)
x, y = create_plot()
ax3.plot(x, y)
plt.show()

# %%
np.random.randn(20)
# Out:
# array([-0.4865647 , -0.10035319, -0.23553791,  0.15241948,  0.61191895,
#         3.13999163, -0.89276661,  1.95732834, -0.05457228,  0.90472102,
#        -0.29387344, -1.22644976, -0.55626753,  0.71483272,  0.834774  ,
#        -0.00383111, -1.72780213,  0.26259925, -0.52602669,  0.61929872])
